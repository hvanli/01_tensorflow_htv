# %%
# import tensorflow as tf 
import numpy as np 
import keras 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# !ls ../data/pizza_steak/test/pizza/
# Out:
# 1001116.jpg  1507019.jpg  2242047.jpg  2944567.jpg  3669673.jpg  556507.jpg
# 1032754.jpg  1512557.jpg  22489.jpg    296426.jpg   3724187.jpg  565112.jpg
# 103708.jpg   153195.jpg   2250611.jpg  2971095.jpg  3724353.jpg  573054.jpg
# 1060407.jpg  1555015.jpg  226472.jpg   2992605.jpg  3724416.jpg  614236.jpg
# 106507.jpg   1594097.jpg  2265512.jpg  2997525.jpg  3728155.jpg  614981.jpg
# 1067986.jpg  1618659.jpg  2276783.jpg  300157.jpg   3729167.jpg  61656.jpg
# 1106738.jpg  1636919.jpg  2296393.jpg  3042459.jpg  373847.jpg	 625434.jpg
# 1119571.jpg  1655630.jpg  2320458.jpg  3049449.jpg  3754474.jpg  645087.jpg
# 11297.jpg    1686938.jpg  2323860.jpg  3092704.jpg  3758160.jpg  648055.jpg
# 1152100.jpg  1687143.jpg  2343304.jpg  309892.jpg   376625.jpg	 65128.jpg
# 1179703.jpg  1691503.jpg  2392727.jpg  3174637.jpg  3770514.jpg  666569.jpg
# 1180001.jpg  1694874.jpg  2398925.jpg  321526.jpg   3784357.jpg  678708.jpg
# 1180273.jpg  1765727.jpg  2406842.jpg  3216107.jpg  3785667.jpg  714866.jpg
# 1183595.jpg  177513.jpg   242976.jpg   3248869.jpg  3793004.jpg  723745.jpg
# 1202689.jpg  1843754.jpg  2478048.jpg  324942.jpg   380739.jpg	 724290.jpg
# 121960.jpg   1895182.jpg  2478221.jpg  3261551.jpg  3814200.jpg  728260.jpg
# 1220156.jpg  1925494.jpg  248199.jpg   3281205.jpg  3827990.jpg  729262.jpg
# 1223284.jpg  194643.jpg   2508316.jpg  3282393.jpg  3898047.jpg  771336.jpg
# 1226346.jpg  194784.jpg   2508636.jpg  328965.jpg   3913440.jpg  788315.jpg
# 1228171.jpg  1949644.jpg  2514438.jpg  3296507.jpg  3919151.jpg  790058.jpg
# 124815.jpg   195160.jpg   2517724.jpg  3296907.jpg  395662.jpg	 796922.jpg
# 1265335.jpg  1962101.jpg  2521769.jpg  3316410.jpg  397910.jpg	 800546.jpg
# 1275885.jpg  1980749.jpg  2542065.jpg  331644.jpg   398345.jpg	 80750.jpg
# 1280320.jpg  1983369.jpg  2543207.jpg  335474.jpg   398812.jpg	 833711.jpg
# 129666.jpg   1986128.jpg  254812.jpg   3375083.jpg  40449.jpg	 837119.jpg
# 1315645.jpg  1991586.jpg  2549661.jpg  3376617.jpg  415551.jpg	 849291.jpg
# 1342321.jpg  1999711.jpg  2572488.jpg  3385460.jpg  416067.jpg	 852436.jpg
# 1380247.jpg  2003290.jpg  2582289.jpg  3392194.jpg  418251.jpg	 863509.jpg
# 138961.jpg   2019408.jpg  2583389.jpg  341377.jpg   419962.jpg	 89197.jpg
# 1398213.jpg  204151.jpg   2605853.jpg  3430418.jpg  420409.jpg	 897300.jpg
# 139952.jpg   2082495.jpg  2615100.jpg  343480.jpg   430904.jpg	 930553.jpg
# 139987.jpg   2101820.jpg  2619955.jpg  3442426.jpg  441659.jpg	 94215.jpg
# 140016.jpg   2111981.jpg  2631321.jpg  344397.jpg   447914.jpg	 96357.jpg
# 1412011.jpg  2124579.jpg  2719697.jpg  3456604.jpg  44810.jpg	 969461.jpg
# 1445608.jpg  212995.jpg   2782998.jpg  346091.jpg   457350.jpg	 971934.jpg
# 144631.jpg   2157510.jpg  2827154.jpg  3475871.jpg  476421.jpg	 976107.jpg
# 1459760.jpg  2161321.jpg  2841536.jpg  3486640.jpg  482858.jpg	 979933.jpg
# 1475479.jpg  2165223.jpg  2870405.jpg  3497151.jpg  513415.jpg	 98607.jpg
# 1484836.jpg  2195935.jpg  2871261.jpg  3581181.jpg  522543.jpg	 99604.jpg
# 148765.jpg   2203687.jpg  2880804.jpg  3586083.jpg  53217.jpg	 998005.jpg
# 1503858.jpg  2218680.jpg  2901001.jpg  3612981.jpg  537575.jpg
# 1506213.jpg  2236338.jpg  293433.jpg   3650727.jpg  540882.jpg

# %%
import os 
pizza_train_images = os.listdir("../data/pizza_steak/train/pizza/") 
pizza_files = ["../data/pizza_steak/train/pizza/" + file for file in pizza_train_images]
pizza_files[:5]
# Out:
# ['../data/pizza_steak/train/pizza/1008104.jpg',
#  '../data/pizza_steak/train/pizza/1008144.jpg',
#  '../data/pizza_steak/train/pizza/1008844.jpg',
#  '../data/pizza_steak/train/pizza/1008941.jpg',
#  '../data/pizza_steak/train/pizza/1011404.jpg']

# %%
from PIL import Image
import matplotlib.pyplot as plt 

img = Image.open(pizza_files[0]) 

plt.imshow(img) 
plt.axis("off")
plt.show();

# %%
for dirpath, dirnames, filenames in os.walk("../data/pizza_steak"): 
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'")
# Out:
# There are 2 directories and 0 images in '../data/pizza_steak'
# There are 2 directories and 0 images in '../data/pizza_steak/test'
# There are 0 directories and 250 images in '../data/pizza_steak/test/pizza'
# There are 0 directories and 250 images in '../data/pizza_steak/test/steak'
# There are 2 directories and 0 images in '../data/pizza_steak/train'
# There are 0 directories and 750 images in '../data/pizza_steak/train/pizza'
# There are 0 directories and 750 images in '../data/pizza_steak/train/steak'

# %%
import pathlib 

class_names = sorted([
    d for d in os.listdir("../data/pizza_steak/train/")
    if os.path.isdir(os.path.join("../data/pizza_steak/train/", d))
])
## Better way of gettin class labels 

data_dir = pathlib.Path("../data/pizza_steak/train/")

class_names = (sorted([
    item.name for item in data_dir.iterdir() if item.is_dir()
]))

class_names
# Out:
# ['pizza', 'steak']

# %%
## Visualize a random image 
import random
import matplotlib.image as mpimg

def view_random_image(target_dir, class_name): 
    target_folder = os.path.join(target_dir, class_name)

    random_image = random.sample(os.listdir(target_folder), 1)[0]
    img_path = os.path.join(target_folder, random_image)
    img = mpimg.imread(img_path)

    plt.imshow(img)
    plt.axis("off")
    plt.show();

view_random_image(target_dir="../data/pizza_steak/train/", 
                 class_name="pizza")

# %%
import random 
import matplotlib.image as mpimg


def plot_an_image(data_dir, class_name): 
    target_folder = os.path.join(data_dir, class_name) 
    random_img = random.sample(os.listdir(target_folder), 1)[0] 
    image_path = os.path.join(target_folder, random_img)
    img = mpimg.imread(image_path) 

    plt.imshow(img) 
    plt.title(f"{class_name}\n Image shape: {img.shape}") 
    plt.axis("off") 
    plt.show(); 
    return img 

img = plot_an_image(data_dir="../data/pizza_steak/train/", class_name="steak")

# %%
img.shape
# Out:
# (512, 384, 3)

# %%
import tensorflow as tf
img_resized = tf.image.resize(img, [256, 256]) 
img_resized.shape
# Out:
# TensorShape([256, 256, 3])

# %%
class_names
# Out:
# ['pizza', 'steak']

# %%
## Sample CNN Model 
# 1 preprocess data
import keras 
keras.utils.set_random_seed(42)

batch_size = 32 
img_height = 224 
img_width = 224 

train_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/pizza_steak/train/",
    batch_size=32,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=42,
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/pizza_steak/test/",
    batch_size=32, 
    image_size=(img_height, img_width), 
    shuffle=True, 
    seed=42
)

normalizer = keras.layers.Rescaling(1./255) 
norm_train_ds = train_ds.map(lambda x, y: (normalizer(x), y))
norm_test_ds = test_ds.map(lambda x, y: (normalizer(x), y)) 

# 2. Create CNN Model 

model_a = keras.models.Sequential([
    keras.layers.Conv2D(filters=10, 
                       kernel_size=3, 
                       activation='relu', 
                       input_shape=(img_height, img_width, 3)),
    keras.layers.Conv2D(10, 3, activation='relu'), 
    keras.layers.MaxPool2D(pool_size=2, 
                          padding="valid"), 
    keras.layers.Conv2D(10, 3, activation='relu'), 
    keras.layers.Conv2D(10, 3, activation='relu'), 
    keras.layers.MaxPool2D(2), 
    keras.layers.Flatten(), 
    keras.layers.Dense(1, activation="sigmoid")
]) 

# 3. Compile the model 

model_a.compile(
    loss=keras.losses.BinaryCrossentropy(), 
    optimizer=keras.optimizers.Adam(), 
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss", 
        patience=7, 
        restore_best_weights=True
    )
]

history_a = model_a.fit(
    norm_train_ds, 
    validation_data=norm_test_ds, 
    epochs=20,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Found 1500 files belonging to 2 classes.
# Found 500 files belonging to 2 classes.
# Epoch 1/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - accuracy: 0.6370 - loss: 0.6184 - val_accuracy: 0.8460 - val_loss: 0.4051
# Epoch 2/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8242 - loss: 0.4306 - val_accuracy: 0.8160 - val_loss: 0.4254
# Epoch 3/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8278 - loss: 0.4007 - val_accuracy: 0.7720 - val_loss: 0.4662
# Epoch 4/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8419 - loss: 0.3730 - val_accuracy: 0.8740 - val_loss: 0.3434
# Epoch 5/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8847 - loss: 0.3277 - val_accuracy: 0.8580 - val_loss: 0.3368
# Epoch 6/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9090 - loss: 0.2531 - val_accuracy: 0.8680 - val_loss: 0.3188
# Epoch 7/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9374 - loss: 0.1736 - val_accuracy: 0.8200 - val_loss: 0.4234
# Epoch 8/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9549 - loss: 0.1518 - val_accuracy: 0.8460 - val_loss: 0.3783
# Epoch 9/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9834 - loss: 0.0831 - val_accuracy: 0.8400 - val_loss: 0.4132
# Epoch 10/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9714 - loss: 0.0902 - val_accuracy: 0.8500 - val_loss: 0.4691
# Epoch 11/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9899 - loss: 0.0426 - val_accuracy: 0.8360 - val_loss: 0.5572
# Epoch 12/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9895 - loss: 0.0362 - val_accuracy: 0.8240 - val_loss: 0.6479
# Epoch 13/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9990 - loss: 0.0139 - val_accuracy: 0.8440 - val_loss: 0.6601

# %%
model_a.evaluate(norm_train_ds)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9406 - loss: 0.1802
# [0.1737326830625534, 0.9419999718666077]

# %%
## Practice iteration-1 

## Check data 
import os 
import pathlib 
pizza_train = os.listdir("../data/pizza_steak/train/pizza/") 
pizza_train_filepaths = ["../data/pizza_steak/train/pizza/" + file for file in pizza_train]
pizza_train_filepaths[:5]
# Out:
# ['../data/pizza_steak/train/pizza/1008104.jpg',
#  '../data/pizza_steak/train/pizza/1008144.jpg',
#  '../data/pizza_steak/train/pizza/1008844.jpg',
#  '../data/pizza_steak/train/pizza/1008941.jpg',
#  '../data/pizza_steak/train/pizza/1011404.jpg']

# %%
# list all folders anf files in data path 

for pathdir, folder, file in os.walk("../data/pizza_steak/"):
    print(f"There are {len(folder)} and {len(file)} in '{pathdir}'")
# Out:
# There are 2 and 0 in '../data/pizza_steak/'
# There are 2 and 0 in '../data/pizza_steak/test'
# There are 0 and 250 in '../data/pizza_steak/test/pizza'
# There are 0 and 250 in '../data/pizza_steak/test/steak'
# There are 2 and 0 in '../data/pizza_steak/train'
# There are 0 and 750 in '../data/pizza_steak/train/pizza'
# There are 0 and 750 in '../data/pizza_steak/train/steak'

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import random

def plot_a_random_img(folder, classname): 
    folder_path = os.path.join(folder, classname) 
    rand_img = random.sample(os.listdir(folder_path), 1)[0] 
    img_path = os.path.join(folder_path, rand_img) 

    img = mpimg.imread(img_path) 
    plt.imshow(img) 
    plt.title(f"{classname} / {img.shape}", fontsize=10) 
    plt.axis("off") 
    plt.show() 
    return img

# %%
img = plot_a_random_img(folder="../data/pizza_steak/train", classname="steak")

# %%
resized = tf.image.resize(img, [224, 224])
resized.shape
# Out:
# TensorShape([224, 224, 3])

# %%
# Preporcess data  

import tensorflow as tf 
import pandas as pd 
import keras 
import numpy as np 

batch_size=32 
img_height = 224 
img_width = 224 

train_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/pizza_steak/train/", 
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=42,
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/pizza_steak/test/", 
    batch_size=batch_size, 
    image_size=(img_height, img_width), 
    shuffle=True, 
    seed=42
)

normalizer = keras.layers.Rescaling(1./255) 
norm_train_ds = train_ds.map(lambda x, y: (normalizer(x), y)) 
norm_test_ds = test_ds.map(lambda x, y: (normalizer(x), y)) 

# Create model 

model_b = keras.models.Sequential([
    keras.layers.Conv2D(filters=10, 
                       kernel_size=3, 
                       activation='relu', 
                       input_shape=(img_height, img_width, 3)), 
    keras.layers.Conv2D(10, 3, activation='relu'), 
    keras.layers.MaxPool2D(pool_size=2, 
                          padding="valid"), 
    keras.layers.Conv2D(10, 3, activation='relu'), 
    keras.layers.Conv2D(10, 3, activation='relu'), 
    keras.layers.MaxPool2D(2), 
    keras.layers.Flatten(), 
    keras.layers.Dense(1, activation="sigmoid")
])


# Compile model 

model_b.compile(
    loss=keras.losses.BinaryCrossentropy(), 
    optimizer=keras.optimizers.Adam(), 
    metrics=['accuracy']
) 

model_b.summary() 

# create callbacks 

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        patience=7, 
        restore_best_weights=True
    ), 
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", 
        factor=0.1,
        min_lr=1e-4
    ),
    keras.callbacks.ModelCheckpoint(
        filepath="models.keras",
        monitor='val_loss',
        save_best_only=False
    ),
    keras.callbacks.TensorBoard(
        log_dir='logs/pizza',
    )
]

# Fit the model 

history_b = model_b.fit(
                norm_train_ds, 
                validation_data=norm_test_ds, 
                epochs=20, 
                callbacks=callbacks, 
                verbose=1
            )
# Out:
# Found 1500 files belonging to 2 classes.
# Found 500 files belonging to 2 classes.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 222, 222, 10)   │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 220, 220, 10)   │           910 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 110, 110, 10)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 108, 108, 10)   │           910 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 106, 106, 10)   │           910 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 53, 53, 10)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 28090)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │        28,091 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,101 (121.49 KB)
#  Trainable params: 31,101 (121.49 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.6503 - loss: 0.5885 - val_accuracy: 0.8260 - val_loss: 0.3976 - learning_rate: 0.0010
# Epoch 2/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8124 - loss: 0.4188 - val_accuracy: 0.7360 - val_loss: 0.4993 - learning_rate: 0.0010
# Epoch 3/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8237 - loss: 0.4001 - val_accuracy: 0.7880 - val_loss: 0.4476 - learning_rate: 0.0010
# Epoch 4/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8583 - loss: 0.3396 - val_accuracy: 0.8620 - val_loss: 0.3239 - learning_rate: 0.0010
# Epoch 5/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8861 - loss: 0.2939 - val_accuracy: 0.8600 - val_loss: 0.3103 - learning_rate: 0.0010
# Epoch 6/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9183 - loss: 0.2253 - val_accuracy: 0.8440 - val_loss: 0.3359 - learning_rate: 0.0010
# Epoch 7/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9514 - loss: 0.1457 - val_accuracy: 0.8300 - val_loss: 0.3860 - learning_rate: 0.0010
# Epoch 8/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9497 - loss: 0.1410 - val_accuracy: 0.8300 - val_loss: 0.4326 - learning_rate: 0.0010
# Epoch 9/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9784 - loss: 0.0761 - val_accuracy: 0.8320 - val_loss: 0.5125 - learning_rate: 0.0010
# Epoch 10/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9967 - loss: 0.0352 - val_accuracy: 0.8240 - val_loss: 0.5858 - learning_rate: 0.0010
# Epoch 11/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9920 - loss: 0.0311 - val_accuracy: 0.8060 - val_loss: 0.6919 - learning_rate: 0.0010
# Epoch 12/20
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9985 - loss: 0.0124 - val_accuracy: 0.8080 - val_loss: 0.8394 - learning_rate: 0.0010

# %%
pd.DataFrame(history_b.history).plot()
plt.xlabel("epochs");

# %%
model_b.evaluate(norm_test_ds);
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8760 - loss: 0.2892

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os

# -------------------------
# Config
# -------------------------
SEED = 42
BATCH_SIZE = 32
IMG_HEIGHT = 224
IMG_WIDTH = 224
AUTOTUNE = tf.data.AUTOTUNE

train_dir = "../data/pizza_steak/train/"
test_dir  = "../data/pizza_steak/test/"

# -------------------------
# Load train + validation split (from train folder)
# -------------------------
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=True,
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=True,
)

# Test set (do NOT use for validation)
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    seed=SEED,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    shuffle=False,  # usually better for repeatable evaluation
)

class_names = train_ds.class_names
print("Classes:", class_names)

# -------------------------
# Performance pipeline
# -------------------------
def prepare(ds, training=False):
    if training:
        ds = ds.shuffle(1024, seed=SEED, reshuffle_each_iteration=True)
    return ds.cache().prefetch(AUTOTUNE)

train_ds = prepare(train_ds, training=True)
val_ds   = prepare(val_ds)
test_ds  = prepare(test_ds)

# -------------------------
# Augmentation + normalization (best practice: inside model)
# -------------------------
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal", seed=SEED),
        layers.RandomRotation(0.08, seed=SEED),
        layers.RandomZoom(0.10, seed=SEED),
        layers.RandomContrast(0.10, seed=SEED),
    ],
    name="data_augmentation",
)

# -------------------------
# Build a stronger CNN with regularization
# -------------------------
weight_decay = 1e-4  # L2

inputs = keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)

# Block 1
x = layers.Conv2D(32, 3, padding="same",
                  kernel_regularizer=keras.regularizers.l2(weight_decay))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.MaxPooling2D()(x)
x = layers.Dropout(0.15)(x)

# Block 2
x = layers.Conv2D(64, 3, padding="same",
                  kernel_regularizer=keras.regularizers.l2(weight_decay))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.MaxPooling2D()(x)
x = layers.Dropout(0.20)(x)

# Block 3
x = layers.Conv2D(128, 3, padding="same",
                  kernel_regularizer=keras.regularizers.l2(weight_decay))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.MaxPooling2D()(x)
x = layers.Dropout(0.30)(x)

# Head (better than Flatten for overfitting)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation="relu",
                 kernel_regularizer=keras.regularizers.l2(weight_decay))(x)
x = layers.Dropout(0.40)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs, name="pizza_steak_cnn_v2")

# -------------------------
# Compile
# -------------------------
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.BinaryCrossentropy(),
    metrics=[
        "accuracy",
        keras.metrics.AUC(name="auc"),
        keras.metrics.Precision(name="precision"),
        keras.metrics.Recall(name="recall"),
    ]
)

model.summary()

# -------------------------
# Callbacks (fixed)
# -------------------------
os.makedirs("checkpoints", exist_ok=True)

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=8,
        restore_best_weights=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.3,
        patience=3,
        min_lr=1e-6,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        filepath="checkpoints/best_model.keras",
        monitor="val_loss",
        save_best_only=True,   # ✅ best-only (you had False)
        verbose=1
    ),
    keras.callbacks.TensorBoard(log_dir="logs/pizza_steak_v2"),
]

# -------------------------
# Train
# -------------------------
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks,
    verbose=1
)

# -------------------------
# Final evaluation on test set (real performance)
# -------------------------
test_metrics = model.evaluate(test_ds, verbose=1)
print(dict(zip(model.metrics_names, test_metrics)))
# Out:
# Found 1500 files belonging to 2 classes.
# Using 1200 files for training.
# Found 1500 files belonging to 2 classes.
# Using 300 files for validation.
# Found 500 files belonging to 2 classes.
# Classes: ['pizza', 'steak']
# Model: "pizza_steak_cnn_v2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequent  (None, 224, 224, 3)       0
#  ial)
#
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  batch_normalization (Batch  (None, 224, 224, 32)      128
#  Normalization)
#
#  activation (Activation)     (None, 224, 224, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 32)      0
#  D)
#
#  dropout (Dropout)           (None, 112, 112, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 112, 112, 64)      256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 112, 112, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 56, 56, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 56, 56, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 56, 56, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 128)       0
#
#  global_average_pooling2d (  (None, 128)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 110785 (432.75 KB)
# Trainable params: 110337 (431.00 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# Epoch 1/50
# 38/38 [==============================] - ETA: 0s - loss: 0.5920 - accuracy: 0.7208 - auc: 0.7873 - precision: 0.7089 - recall: 0.7317
# Epoch 1: val_loss improved from inf to 0.73027, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 11s 152ms/step - loss: 0.5920 - accuracy: 0.7208 - auc: 0.7873 - precision: 0.7089 - recall: 0.7317 - val_loss: 0.7303 - val_accuracy: 0.5267 - val_auc: 0.5118 - val_precision: 0.5455 - val_recall: 0.7081 - lr: 0.0010
# Epoch 2/50
# 38/38 [==============================] - ETA: 0s - loss: 0.5143 - accuracy: 0.7667 - auc: 0.8440 - precision: 0.7512 - recall: 0.7844
# Epoch 2: val_loss improved from 0.73027 to 0.72074, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 84ms/step - loss: 0.5143 - accuracy: 0.7667 - auc: 0.8440 - precision: 0.7512 - recall: 0.7844 - val_loss: 0.7207 - val_accuracy: 0.5467 - val_auc: 0.6095 - val_precision: 0.6712 - val_recall: 0.3043 - lr: 0.0010
# Epoch 3/50
# 38/38 [==============================] - ETA: 0s - loss: 0.4886 - accuracy: 0.7808 - auc: 0.8628 - precision: 0.7672 - recall: 0.7946
# Epoch 3: val_loss did not improve from 0.72074
# 38/38 [==============================] - 3s 69ms/step - loss: 0.4886 - accuracy: 0.7808 - auc: 0.8628 - precision: 0.7672 - recall: 0.7946 - val_loss: 0.7246 - val_accuracy: 0.5233 - val_auc: 0.6687 - val_precision: 0.6875 - val_recall: 0.2050 - lr: 0.0010
# Epoch 4/50
# 38/38 [==============================] - ETA: 0s - loss: 0.4722 - accuracy: 0.8008 - auc: 0.8722 - precision: 0.7859 - recall: 0.8166
# Epoch 4: val_loss improved from 0.72074 to 0.70226, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 70ms/step - loss: 0.4722 - accuracy: 0.8008 - auc: 0.8722 - precision: 0.7859 - recall: 0.8166 - val_loss: 0.7023 - val_accuracy: 0.5867 - val_auc: 0.6755 - val_precision: 0.7403 - val_recall: 0.3540 - lr: 0.0010
# Epoch 5/50
# 38/38 [==============================] - ETA: 0s - loss: 0.4526 - accuracy: 0.8058 - auc: 0.8855 - precision: 0.7862 - recall: 0.8302
# Epoch 5: val_loss improved from 0.70226 to 0.69315, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 69ms/step - loss: 0.4526 - accuracy: 0.8058 - auc: 0.8855 - precision: 0.7862 - recall: 0.8302 - val_loss: 0.6932 - val_accuracy: 0.5733 - val_auc: 0.7787 - val_precision: 0.8367 - val_recall: 0.2547 - lr: 0.0010
# Epoch 6/50
# 38/38 [==============================] - ETA: 0s - loss: 0.4319 - accuracy: 0.8067 - auc: 0.8952 - precision: 0.7950 - recall: 0.8166
# Epoch 6: val_loss improved from 0.69315 to 0.63395, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 69ms/step - loss: 0.4319 - accuracy: 0.8067 - auc: 0.8952 - precision: 0.7950 - recall: 0.8166 - val_loss: 0.6339 - val_accuracy: 0.7300 - val_auc: 0.7754 - val_precision: 0.7899 - val_recall: 0.6770 - lr: 0.0010
# Epoch 7/50
# 34/38 [=========================>....] - ETA: 0s - loss: 0.4045 - accuracy: 0.8302 - auc: 0.9099 - precision: 0.8165 - recall: 0.8444
# Epoch 7: val_loss improved from 0.63395 to 0.62817, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 2s 41ms/step - loss: 0.4172 - accuracy: 0.8208 - auc: 0.9035 - precision: 0.8066 - recall: 0.8353 - val_loss: 0.6282 - val_accuracy: 0.6467 - val_auc: 0.8090 - val_precision: 0.6104 - val_recall: 0.9441 - lr: 0.0010
# Epoch 8/50
# 38/38 [==============================] - ETA: 0s - loss: 0.4027 - accuracy: 0.8275 - auc: 0.9117 - precision: 0.8121 - recall: 0.8438
# Epoch 8: val_loss did not improve from 0.62817
# 38/38 [==============================] - 3s 68ms/step - loss: 0.4027 - accuracy: 0.8275 - auc: 0.9117 - precision: 0.8121 - recall: 0.8438 - val_loss: 0.6571 - val_accuracy: 0.6333 - val_auc: 0.7659 - val_precision: 0.5985 - val_recall: 0.9627 - lr: 0.0010
# Epoch 9/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3979 - accuracy: 0.8442 - auc: 0.9144 - precision: 0.8372 - recall: 0.8472
# Epoch 9: val_loss did not improve from 0.62817
# 38/38 [==============================] - 3s 67ms/step - loss: 0.3979 - accuracy: 0.8442 - auc: 0.9144 - precision: 0.8372 - recall: 0.8472 - val_loss: 0.6474 - val_accuracy: 0.6600 - val_auc: 0.7586 - val_precision: 0.6245 - val_recall: 0.9193 - lr: 0.0010
# Epoch 10/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3920 - accuracy: 0.8517 - auc: 0.9173 - precision: 0.8352 - recall: 0.8693
# Epoch 10: val_loss improved from 0.62817 to 0.50184, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 68ms/step - loss: 0.3920 - accuracy: 0.8517 - auc: 0.9173 - precision: 0.8352 - recall: 0.8693 - val_loss: 0.5018 - val_accuracy: 0.8167 - val_auc: 0.9061 - val_precision: 0.9274 - val_recall: 0.7143 - lr: 0.0010
# Epoch 11/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3832 - accuracy: 0.8508 - auc: 0.9203 - precision: 0.8417 - recall: 0.8574
# Epoch 11: val_loss improved from 0.50184 to 0.47398, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 69ms/step - loss: 0.3832 - accuracy: 0.8508 - auc: 0.9203 - precision: 0.8417 - recall: 0.8574 - val_loss: 0.4740 - val_accuracy: 0.8300 - val_auc: 0.9076 - val_precision: 0.8819 - val_recall: 0.7888 - lr: 0.0010
# Epoch 12/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3772 - accuracy: 0.8458 - auc: 0.9241 - precision: 0.8311 - recall: 0.8608
# Epoch 12: val_loss improved from 0.47398 to 0.44796, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 69ms/step - loss: 0.3772 - accuracy: 0.8458 - auc: 0.9241 - precision: 0.8311 - recall: 0.8608 - val_loss: 0.4480 - val_accuracy: 0.8267 - val_auc: 0.9011 - val_precision: 0.8225 - val_recall: 0.8634 - lr: 0.0010
# Epoch 13/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3505 - accuracy: 0.8725 - auc: 0.9352 - precision: 0.8658 - recall: 0.8761
# Epoch 13: val_loss improved from 0.44796 to 0.44035, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 69ms/step - loss: 0.3505 - accuracy: 0.8725 - auc: 0.9352 - precision: 0.8658 - recall: 0.8761 - val_loss: 0.4404 - val_accuracy: 0.8267 - val_auc: 0.8974 - val_precision: 0.8428 - val_recall: 0.8323 - lr: 0.0010
# Epoch 14/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3440 - accuracy: 0.8633 - auc: 0.9376 - precision: 0.8501 - recall: 0.8761
# Epoch 14: val_loss improved from 0.44035 to 0.42383, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 69ms/step - loss: 0.3440 - accuracy: 0.8633 - auc: 0.9376 - precision: 0.8501 - recall: 0.8761 - val_loss: 0.4238 - val_accuracy: 0.8300 - val_auc: 0.9277 - val_precision: 0.9231 - val_recall: 0.7453 - lr: 0.0010
# Epoch 15/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3487 - accuracy: 0.8617 - auc: 0.9361 - precision: 0.8531 - recall: 0.8676
# Epoch 15: val_loss did not improve from 0.42383
# 38/38 [==============================] - 3s 68ms/step - loss: 0.3487 - accuracy: 0.8617 - auc: 0.9361 - precision: 0.8531 - recall: 0.8676 - val_loss: 0.5778 - val_accuracy: 0.6967 - val_auc: 0.8628 - val_precision: 0.6483 - val_recall: 0.9503 - lr: 0.0010
# Epoch 16/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3361 - accuracy: 0.8758 - auc: 0.9401 - precision: 0.8679 - recall: 0.8812
# Epoch 16: val_loss did not improve from 0.42383
# 38/38 [==============================] - 3s 67ms/step - loss: 0.3361 - accuracy: 0.8758 - auc: 0.9401 - precision: 0.8679 - recall: 0.8812 - val_loss: 0.4496 - val_accuracy: 0.8033 - val_auc: 0.9357 - val_precision: 0.9554 - val_recall: 0.6646 - lr: 0.0010
# Epoch 17/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.8808 - auc: 0.9418 - precision: 0.8717 - recall: 0.8879
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 17: val_loss did not improve from 0.42383
# 38/38 [==============================] - 3s 68ms/step - loss: 0.3331 - accuracy: 0.8808 - auc: 0.9418 - precision: 0.8717 - recall: 0.8879 - val_loss: 0.6671 - val_accuracy: 0.6667 - val_auc: 0.9014 - val_precision: 0.6178 - val_recall: 0.9938 - lr: 0.0010
# Epoch 18/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3194 - accuracy: 0.8817 - auc: 0.9476 - precision: 0.8769 - recall: 0.8829
# Epoch 18: val_loss did not improve from 0.42383
# 38/38 [==============================] - 3s 68ms/step - loss: 0.3194 - accuracy: 0.8817 - auc: 0.9476 - precision: 0.8769 - recall: 0.8829 - val_loss: 0.4790 - val_accuracy: 0.7700 - val_auc: 0.9442 - val_precision: 0.7035 - val_recall: 0.9876 - lr: 3.0000e-04
# Epoch 19/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3116 - accuracy: 0.8800 - auc: 0.9495 - precision: 0.8666 - recall: 0.8930
# Epoch 19: val_loss improved from 0.42383 to 0.34546, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 2s 41ms/step - loss: 0.3116 - accuracy: 0.8800 - auc: 0.9495 - precision: 0.8666 - recall: 0.8930 - val_loss: 0.3455 - val_accuracy: 0.8600 - val_auc: 0.9483 - val_precision: 0.8287 - val_recall: 0.9317 - lr: 3.0000e-04
# Epoch 20/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3051 - accuracy: 0.8817 - auc: 0.9515 - precision: 0.8706 - recall: 0.8913
# Epoch 20: val_loss did not improve from 0.34546
# 38/38 [==============================] - 3s 67ms/step - loss: 0.3051 - accuracy: 0.8817 - auc: 0.9515 - precision: 0.8706 - recall: 0.8913 - val_loss: 0.3461 - val_accuracy: 0.8567 - val_auc: 0.9498 - val_precision: 0.8207 - val_recall: 0.9379 - lr: 3.0000e-04
# Epoch 21/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3086 - accuracy: 0.8808 - auc: 0.9511 - precision: 0.8729 - recall: 0.8862
# Epoch 21: val_loss did not improve from 0.34546
# 38/38 [==============================] - 3s 67ms/step - loss: 0.3086 - accuracy: 0.8808 - auc: 0.9511 - precision: 0.8729 - recall: 0.8862 - val_loss: 0.3903 - val_accuracy: 0.8367 - val_auc: 0.9483 - val_precision: 0.7772 - val_recall: 0.9752 - lr: 3.0000e-04
# Epoch 22/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3102 - accuracy: 0.8792 - auc: 0.9495 - precision: 0.8688 - recall: 0.8879
# Epoch 22: val_loss improved from 0.34546 to 0.33335, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 69ms/step - loss: 0.3102 - accuracy: 0.8792 - auc: 0.9495 - precision: 0.8688 - recall: 0.8879 - val_loss: 0.3333 - val_accuracy: 0.8633 - val_auc: 0.9494 - val_precision: 0.8409 - val_recall: 0.9193 - lr: 3.0000e-04
# Epoch 23/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2962 - accuracy: 0.8892 - auc: 0.9556 - precision: 0.8800 - recall: 0.8964
# Epoch 23: val_loss did not improve from 0.33335
# 38/38 [==============================] - 3s 68ms/step - loss: 0.2962 - accuracy: 0.8892 - auc: 0.9556 - precision: 0.8800 - recall: 0.8964 - val_loss: 0.3813 - val_accuracy: 0.8500 - val_auc: 0.9481 - val_precision: 0.7990 - val_recall: 0.9627 - lr: 3.0000e-04
# Epoch 24/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.8900 - auc: 0.9538 - precision: 0.8815 - recall: 0.8964
# Epoch 24: val_loss did not improve from 0.33335
# 38/38 [==============================] - 3s 67ms/step - loss: 0.3001 - accuracy: 0.8900 - auc: 0.9538 - precision: 0.8815 - recall: 0.8964 - val_loss: 0.3559 - val_accuracy: 0.8667 - val_auc: 0.9504 - val_precision: 0.8235 - val_recall: 0.9565 - lr: 3.0000e-04
# Epoch 25/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3048 - accuracy: 0.8858 - auc: 0.9527 - precision: 0.8669 - recall: 0.9066
# Epoch 25: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 25: val_loss did not improve from 0.33335
# 38/38 [==============================] - 3s 68ms/step - loss: 0.3048 - accuracy: 0.8858 - auc: 0.9527 - precision: 0.8669 - recall: 0.9066 - val_loss: 0.3533 - val_accuracy: 0.8600 - val_auc: 0.9473 - val_precision: 0.8182 - val_recall: 0.9503 - lr: 3.0000e-04
# Epoch 26/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2876 - accuracy: 0.8925 - auc: 0.9581 - precision: 0.8846 - recall: 0.8981
# Epoch 26: val_loss improved from 0.33335 to 0.32878, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 68ms/step - loss: 0.2876 - accuracy: 0.8925 - auc: 0.9581 - precision: 0.8846 - recall: 0.8981 - val_loss: 0.3288 - val_accuracy: 0.8900 - val_auc: 0.9469 - val_precision: 0.9103 - val_recall: 0.8820 - lr: 9.0000e-05
# Epoch 27/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.8983 - auc: 0.9620 - precision: 0.8885 - recall: 0.9066
# Epoch 27: val_loss improved from 0.32878 to 0.32769, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 69ms/step - loss: 0.2762 - accuracy: 0.8983 - auc: 0.9620 - precision: 0.8885 - recall: 0.9066 - val_loss: 0.3277 - val_accuracy: 0.8767 - val_auc: 0.9492 - val_precision: 0.8483 - val_recall: 0.9379 - lr: 9.0000e-05
# Epoch 28/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2825 - accuracy: 0.9008 - auc: 0.9598 - precision: 0.8904 - recall: 0.9100
# Epoch 28: val_loss improved from 0.32769 to 0.32066, saving model to checkpoints/best_model.keras
# 38/38 [==============================] - 3s 70ms/step - loss: 0.2825 - accuracy: 0.9008 - auc: 0.9598 - precision: 0.8904 - recall: 0.9100 - val_loss: 0.3207 - val_accuracy: 0.8733 - val_auc: 0.9503 - val_precision: 0.8436 - val_recall: 0.9379 - lr: 9.0000e-05
# Epoch 29/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.8967 - auc: 0.9592 - precision: 0.8843 - recall: 0.9083
# Epoch 29: val_loss did not improve from 0.32066
# 38/38 [==============================] - 3s 67ms/step - loss: 0.2839 - accuracy: 0.8967 - auc: 0.9592 - precision: 0.8843 - recall: 0.9083 - val_loss: 0.3304 - val_accuracy: 0.8733 - val_auc: 0.9509 - val_precision: 0.8398 - val_recall: 0.9441 - lr: 9.0000e-05
# Epoch 30/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2800 - accuracy: 0.8967 - auc: 0.9603 - precision: 0.8856 - recall: 0.9066
# Epoch 30: val_loss did not improve from 0.32066
# 38/38 [==============================] - 3s 67ms/step - loss: 0.2800 - accuracy: 0.8967 - auc: 0.9603 - precision: 0.8856 - recall: 0.9066 - val_loss: 0.3330 - val_accuracy: 0.8667 - val_auc: 0.9490 - val_precision: 0.8270 - val_recall: 0.9503 - lr: 9.0000e-05
# Epoch 31/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.8950 - auc: 0.9601 - precision: 0.8891 - recall: 0.8981
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 31: val_loss did not improve from 0.32066
# 38/38 [==============================] - 1s 38ms/step - loss: 0.2804 - accuracy: 0.8950 - auc: 0.9601 - precision: 0.8891 - recall: 0.8981 - val_loss: 0.3552 - val_accuracy: 0.8600 - val_auc: 0.9467 - val_precision: 0.8083 - val_recall: 0.9689 - lr: 9.0000e-05
# Epoch 32/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.9000 - auc: 0.9633 - precision: 0.8838 - recall: 0.9168
# Epoch 32: val_loss did not improve from 0.32066
# 38/38 [==============================] - 3s 67ms/step - loss: 0.2732 - accuracy: 0.9000 - auc: 0.9633 - precision: 0.8838 - recall: 0.9168 - val_loss: 0.3494 - val_accuracy: 0.8567 - val_auc: 0.9495 - val_precision: 0.8105 - val_recall: 0.9565 - lr: 2.7000e-05
# Epoch 33/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2589 - accuracy: 0.9108 - auc: 0.9682 - precision: 0.8925 - recall: 0.9304
# Epoch 33: val_loss did not improve from 0.32066
# 38/38 [==============================] - 3s 68ms/step - loss: 0.2589 - accuracy: 0.9108 - auc: 0.9682 - precision: 0.8925 - recall: 0.9304 - val_loss: 0.3308 - val_accuracy: 0.8733 - val_auc: 0.9496 - val_precision: 0.8398 - val_recall: 0.9441 - lr: 2.7000e-05
# Epoch 34/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2640 - accuracy: 0.9092 - auc: 0.9661 - precision: 0.8909 - recall: 0.9287
# Epoch 34: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 34: val_loss did not improve from 0.32066
# 38/38 [==============================] - 3s 67ms/step - loss: 0.2640 - accuracy: 0.9092 - auc: 0.9661 - precision: 0.8909 - recall: 0.9287 - val_loss: 0.3342 - val_accuracy: 0.8700 - val_auc: 0.9503 - val_precision: 0.8315 - val_recall: 0.9503 - lr: 2.7000e-05
# Epoch 35/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0.9000 - auc: 0.9642 - precision: 0.8863 - recall: 0.9134
# Epoch 35: val_loss did not improve from 0.32066
# 38/38 [==============================] - 3s 67ms/step - loss: 0.2682 - accuracy: 0.9000 - auc: 0.9642 - precision: 0.8863 - recall: 0.9134 - val_loss: 0.3341 - val_accuracy: 0.8667 - val_auc: 0.9500 - val_precision: 0.8270 - val_recall: 0.9503 - lr: 8.1000e-06
# Epoch 36/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.9050 - auc: 0.9649 - precision: 0.8978 - recall: 0.9100
# Epoch 36: val_loss did not improve from 0.32066
# 38/38 [==============================] - 3s 66ms/step - loss: 0.2663 - accuracy: 0.9050 - auc: 0.9649 - precision: 0.8978 - recall: 0.9100 - val_loss: 0.3305 - val_accuracy: 0.8633 - val_auc: 0.9503 - val_precision: 0.8261 - val_recall: 0.9441 - lr: 8.1000e-06
# 16/16 [==============================] - 1s 30ms/step - loss: 0.2493 - accuracy: 0.9140 - auc: 0.9753 - precision: 0.8764 - recall: 0.9640
# {'loss': 0.24932868778705597, 'accuracy': 0.9139999747276306, 'auc': 0.9753279685974121, 'precision': 0.8763636350631714, 'recall': 0.9639999866485596}
