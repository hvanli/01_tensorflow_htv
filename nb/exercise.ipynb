# %%
import tensorflow as tf 
tf.config.optimizer.set_jit(False)
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

print(tf.__version__)
# Out:
# 2.17.0

# %%
import tensorflow as tf
import torch

print("=== TensorFlow ===")
print("GPU Available ✔️" if tf.config.list_physical_devices('GPU') else "GPU NOT Available ❌")

print("\n=== PyTorch ===")
print("GPU Available ✔️" if torch.cuda.is_available() else "GPU NOT Available ❌")
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# === TensorFlow ===
# GPU Available ✔️
#
# === PyTorch ===
# GPU Available ✔️
# NVIDIA GeForce RTX 5070 Ti Laptop GPU

# %%
X = tf.range(-10, 10, delta=3, dtype=tf.float32)
y = tf.range(0, 20, delta=3, dtype=tf.float32)

# %%
plt.scatter(X, y)

# %%
y == X + 50
# Out:
# <tf.Tensor: shape=(7,), dtype=bool, numpy=array([False, False, False, False, False, False, False])>

# %%
house_info = tf.constant(['bedroom', 'bathroom', 'garage'])
house_price = tf.constant([975350])

house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([975350], dtype=int32)>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape

input_shape, output_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %%
X[0].ndim, y[0].ndim
# Out:
# (0, 0)

# %%
# Set random sreversed
tf.random.set_seed(42)

# 2. Create a model using the Sequential Apiabs

model = tf.keras.Sequential([
    # tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(50, activation=None),
    tf.keras.layers.Dense(1)
])

# 3. Compile the mmodel

# model.compile(loss=tf.keras.losses.mae,
#              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
#              metrics=['mae', 'mse'])

model.compile(loss=tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
             metrics=['mae', 'mse'])

# 4. Fit the model 

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 957ms/step - loss: 9.0427 - mae: 9.0427 - mse: 114.7628
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.1817 - mae: 9.1817 - mse: 123.2994
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.9987 - mae: 8.9987 - mse: 117.8107
# Epoch 4/100
# 1/1 [==============================] - 0s 11ms/step - loss: 8.7316 - mae: 8.7316 - mse: 109.8488
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.6797 - mae: 8.6797 - mse: 105.4895
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.5846 - mae: 8.5846 - mse: 103.1774
# Epoch 7/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8.4575 - mae: 8.4575 - mse: 102.2962
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.4181 - mae: 8.4181 - mse: 102.6184
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.3183 - mae: 8.3183 - mse: 100.2109
# Epoch 10/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.1484 - mae: 8.1484 - mse: 95.9335
# Epoch 11/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.0905 - mae: 8.0905 - mse: 90.5381
# Epoch 12/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.0145 - mae: 8.0145 - mse: 86.4922
# Epoch 13/100
# 1/1 [==============================] - 0s 4ms/step - loss: 7.9097 - mae: 7.9097 - mse: 83.4009
# Epoch 14/100
# 1/1 [==============================] - 0s 4ms/step - loss: 7.7787 - mae: 7.7787 - mse: 81.0491
# Epoch 15/100
# 1/1 [==============================] - 0s 4ms/step - loss: 7.6235 - mae: 7.6235 - mse: 79.3430
# Epoch 16/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.4455 - mae: 7.4455 - mse: 78.2742
# Epoch 17/100
# 1/1 [==============================] - 0s 4ms/step - loss: 7.3353 - mae: 7.3353 - mse: 77.8957
# Epoch 18/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.2258 - mae: 7.2258 - mse: 75.7335
# Epoch 19/100
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0505 - mae: 7.0505 - mse: 72.0198
# Epoch 20/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8251 - mae: 6.8251 - mse: 67.1348
# Epoch 21/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.6778 - mae: 6.6778 - mse: 63.1703
# Epoch 22/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.5008 - mae: 6.5008 - mse: 59.9294
# Epoch 23/100
# 1/1 [==============================] - 0s 5ms/step - loss: 6.2992 - mae: 6.2992 - mse: 57.3208
# Epoch 24/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1157 - mae: 6.1157 - mse: 53.4397
# Epoch 25/100
# 1/1 [==============================] - 0s 6ms/step - loss: 5.9051 - mae: 5.9051 - mse: 50.2432
# Epoch 26/100
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7380 - mae: 5.7380 - mse: 47.6729
# Epoch 27/100
# 1/1 [==============================] - 0s 5ms/step - loss: 5.5043 - mae: 5.5043 - mse: 43.8398
# Epoch 28/100
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2615 - mae: 5.2615 - mse: 39.0734
# Epoch 29/100
# 1/1 [==============================] - 0s 5ms/step - loss: 5.0357 - mae: 5.0357 - mse: 35.1300
# Epoch 30/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.7743 - mae: 4.7743 - mse: 31.8286
# Epoch 31/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.4881 - mae: 4.4881 - mse: 29.1062
# Epoch 32/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.2116 - mae: 4.2116 - mse: 25.4370
# Epoch 33/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.9375 - mae: 3.9375 - mse: 22.4246
# Epoch 34/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6318 - mae: 3.6318 - mse: 18.6701
# Epoch 35/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.3155 - mae: 3.3155 - mse: 15.6244
# Epoch 36/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.0152 - mae: 3.0152 - mse: 13.1816
# Epoch 37/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6517 - mae: 2.6517 - mse: 10.1674
# Epoch 38/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.3390 - mae: 2.3390 - mse: 7.0389
# Epoch 39/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9959 - mae: 1.9959 - mse: 4.7546
# Epoch 40/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6067 - mae: 1.6067 - mse: 3.0261
# Epoch 41/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1725 - mae: 1.1725 - mse: 1.7494
# Epoch 42/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8039 - mae: 0.8039 - mse: 0.9843
# Epoch 43/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3200 - mae: 0.3200 - mse: 0.1483
# Epoch 44/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4349 - mae: 0.4349 - mse: 0.2527
# Epoch 45/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5044 - mae: 0.5044 - mse: 0.3840
# Epoch 46/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8130 - mae: 0.8130 - mse: 0.6708
# Epoch 47/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0460 - mae: 1.0460 - mse: 1.1010
# Epoch 48/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1633 - mae: 1.1633 - mse: 1.3706
# Epoch 49/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1781 - mae: 1.1781 - mse: 1.3914
# Epoch 50/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1034 - mae: 1.1034 - mse: 1.2330
# Epoch 51/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9511 - mae: 0.9511 - mse: 1.0684
# Epoch 52/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8623 - mae: 0.8623 - mse: 1.1262
# Epoch 53/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6738 - mae: 0.6738 - mse: 0.6918
# Epoch 54/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4837 - mae: 0.4837 - mse: 0.2341
# Epoch 55/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4344 - mae: 0.4344 - mse: 0.2757
# Epoch 56/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2664 - mae: 0.2664 - mse: 0.0948
# Epoch 57/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2952 - mae: 0.2952 - mse: 0.1268
# Epoch 58/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4337 - mae: 0.4337 - mse: 0.2854
# Epoch 59/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4607 - mae: 0.4607 - mse: 0.2417
# Epoch 60/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4624 - mae: 0.4624 - mse: 0.2198
# Epoch 61/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4453 - mae: 0.4453 - mse: 0.2993
# Epoch 62/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4778 - mae: 0.4778 - mse: 0.3302
# Epoch 63/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3014 - mae: 0.3014 - mse: 0.1338
# Epoch 64/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2275 - mae: 0.2275 - mse: 0.0747
# Epoch 65/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3845 - mae: 0.3845 - mse: 0.1974
# Epoch 66/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2103 - mae: 0.2103 - mse: 0.0591
# Epoch 67/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3568 - mae: 0.3568 - mse: 0.1864
# Epoch 68/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5024 - mae: 0.5024 - mse: 0.3690
# Epoch 69/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3932 - mae: 0.3932 - mse: 0.2149
# Epoch 70/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3436 - mae: 0.3436 - mse: 0.1190
# Epoch 71/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3466 - mae: 0.3466 - mse: 0.1735
# Epoch 72/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2987 - mae: 0.2987 - mse: 0.1271
# Epoch 73/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1191 - mae: 0.1191 - mse: 0.0186
# Epoch 74/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3082 - mae: 0.3082 - mse: 0.1267
# Epoch 75/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2172 - mae: 0.2172 - mse: 0.0681
# Epoch 76/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2946 - mae: 0.2946 - mse: 0.1267
# Epoch 77/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4436 - mae: 0.4436 - mse: 0.2946
# Epoch 78/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3755 - mae: 0.3755 - mse: 0.2040
# Epoch 79/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3128 - mae: 0.3128 - mse: 0.1050
# Epoch 80/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4123 - mae: 0.4123 - mse: 0.2401
# Epoch 81/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3961 - mae: 0.3961 - mse: 0.2114
# Epoch 82/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1266 - mae: 0.1266 - mse: 0.0242
# Epoch 83/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2889 - mae: 0.2889 - mse: 0.1109
# Epoch 84/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3178 - mae: 0.3178 - mse: 0.1356
# Epoch 85/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1361 - mae: 0.1361 - mse: 0.0255
# Epoch 86/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1803 - mae: 0.1803 - mse: 0.0470
# Epoch 87/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1517 - mae: 0.1517 - mse: 0.0333
# Epoch 88/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1080 - mae: 0.1080 - mse: 0.0169
# Epoch 89/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0550 - mae: 0.0550 - mse: 0.0040
# Epoch 90/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2708 - mae: 0.2708 - mse: 0.0977
# Epoch 91/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2990 - mae: 0.2990 - mse: 0.1187
# Epoch 92/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1501 - mae: 0.1501 - mse: 0.0260
# Epoch 93/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1743 - mae: 0.1743 - mse: 0.0456
# Epoch 94/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1404 - mae: 0.1404 - mse: 0.0287
# Epoch 95/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1281 - mae: 0.1281 - mse: 0.0219
# Epoch 96/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0906 - mae: 0.0906 - mse: 0.0119
# Epoch 97/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2094 - mae: 0.2094 - mse: 0.0582
# Epoch 98/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2088 - mae: 0.2088 - mse: 0.0585
# Epoch 99/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1156 - mae: 0.1156 - mse: 0.0172
# Epoch 100/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2548 - mae: 0.2548 - mse: 0.0885

# %%
model.predict([10])
# Out:
# 1/1 [==============================] - 0s 47ms/step
# array([[19.710758]], dtype=float32)

# %%
X
# Out:
# <tf.Tensor: shape=(7,), dtype=float32, numpy=array([-10.,  -7.,  -4.,  -1.,   2.,   5.,   8.], dtype=float32)>

# %% [markdown]
# # Common ways to improve a deep model
#
# 1. Adding layers
# 2. Increase the number of hidden units
# 3. Change the activation functions
# 4. Change the optimization functions
# 5. Change the learning rate
# 6. Fitting on more data
# 7. Fitting for longer (epochs)

# %% [markdown]
# # Evaluating a model
# "Visualize, visualize, visualize"
#
# It is a good idea to visualize
# 1. Data
# 2. Model itself
# 3. Training - how does a model while it learns
# 4. The predictions of the model - predictions vs ground truth

# %%
# Work on a bigger data sget_ipython

X = tf.range(-100, 100, delta=4)
y = X + 10 
X, y
# Out:
# (<tf.Tensor: shape=(50,), dtype=int32, numpy=
#  array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#          -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#          -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#           32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#           76,   80,   84,   88,   92,   96], dtype=int32)>,
#  <tf.Tensor: shape=(50,), dtype=int32, numpy=
#  array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#         -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#          14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#          66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>)

# %%
plt.scatter(X, y)

# %%
plt.plot(X, y)

# %% [markdown]
# # Three sets
# 1. Training - %70-%80
# 2. Validation Set %10-%15
# 3. Test Set %10 - %15

# %%
# dataset = tf.data.Dataset.from_tensor_slices((X, y))
# dataset = dataset.shuffle(buffer_size=len(X), seed=42)

# train_size = int(0.8 * len(X))
# train_ds = dataset.take(train_size)
# test_ds = dataset.skip(train_size)

# %%
from sklearn.model_selection import train_test_split

X_np = X.numpy()
y_np = y.numpy()
X_train, X_test, y_train, y_test = train_test_split(X_np, y_np, test_size=0.2, random_state=42)

X_train = tf.constant(X_train, dtype=tf.float32)
X_test = tf.constant(X_test, dtype=tf.float32) 
y_train = tf.constant(y_train, dtype=tf.float32) 
y_test = tf.constant(y_test, dtype=tf.float32)

# %%
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=50, verbose=0)

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 73ms/step - loss: 2.0933 - mae: 2.0933 - mse: 6.8140
# [2.093303918838501, 2.093303918838501, 6.814006805419922]

# %%
# Visualize data

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_train, y_train, c='b', label="Training data")
plt.scatter(X_test, y_test, c='g', label="Test Data")
plt.legend();

# %%
X_train.shape
# Out:
# TensorShape([40])

# %%
# 1 Create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1])
])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae, 
             optimizer=tf.keras.optimizers.SGD(), 
             metrics=['mae', 'mse'])

# # 3. Fit the model 
# model.fit(X_train, y_train, epochs=100)

# %%
## 1. Visualize the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Create model which builds automatically by defining the input_shape argument
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1]),
    # tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu')
])

model.compile(loss=tf.keras.losses.mae, 
             optimizer=tf.keras.optimizers.SGD(), 
             metrics=['mae', 'mse'])


model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1)                 2
#
#  dense_4 (Dense)             (None, 100)               200
#
# =================================================================
# Total params: 202 (808.00 Byte)
# Trainable params: 202 (808.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1)                 2
#
#  dense_4 (Dense)             (None, 100)               200
#
# =================================================================
# Total params: 202 (808.00 Byte)
# Trainable params: 202 (808.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 63ms/step - loss: 11.4181 - mae: 11.4181 - mse: 241.7901
# [11.418105125427246, 11.418105125427246, 241.79013061523438]

# %%
# total_param : total number of parameters in the model 
# trainable parameters : the parameters (patterns) the model update as it trains. 
# non trainable parameters : When we import a pre built/trained model we want to freeze parameters transferred model

# %%
# Weights and biases - Trainable/Learnable params

# %%
from tensorflow.keras.utils import plot_model

plot_model(model=model, show_shapes=True)

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, input_shape=[1], name="input_layer"),
    tf.keras.layers.Dense(1, name="output_layer")
], name="model_1")

model.compile(loss=tf.keras.losses.mae, 
             optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
             metrics=['mae'])

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (Dense)         (None, 10)                20
#
#  output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 31 (124.00 Byte)
# Trainable params: 31 (124.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 56ms/step - loss: 10.3165 - mae: 10.3165
# [10.316484451293945, 10.316484451293945]

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (Dense)         (None, 10)                20
#
#  output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 31 (124.00 Byte)
# Trainable params: 31 (124.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_model(model=model, show_shapes=True)

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
def plot_pred_vs_true(X_train, 
                      y_train, 
                      X_test, 
                      y_true, 
                      y_pred):
    plt.figure(figsize=(10, 7))
    plt.scatter(X_test, y_pred, c='b', label="Predictions")
    plt.scatter(X_test, y_true, c="r", label="Testing Data")
    plt.scatter(X_train, y_train, c='g', label="Training Data")
    plt.legend();

# %%
plot_pred_vs_true(X_train, y_train, X_test, y_test, y_pred)

# %% [markdown]
# ### Evaluating the model's predictions with regression evaluation metrics
#
# There are two main metrics to evaluate a regression model.png
#
# 1. Mean absolute error `mae` On average how wrong our predictions
# 2. MSE - Mean Square Error `mse` Square the avarege error
# 3. Huber - Combination of MAE and MSE

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 13ms/step - loss: 10.3165 - mae: 10.3165
# [10.316484451293945, 10.316484451293945]

# %%
mae = tf.reduce_mean(tf.abs(y_test - tf.constant(y_pred)))
print(mae.numpy())
# Out:
# 49.897903

# %%
tf.reduce_mean((tf.metrics.mean_absolute_error(y_test, tf.constant(y_pred)))).numpy()
# Out:
# 49.89791

# %%
y_pred = tf.constant(y_pred)
y_test = tf.reshape(y_test, shape=(10, 1))
y_test, y_pred
# Out:
# (<tf.Tensor: shape=(10, 1), dtype=float32, numpy=
#  array([[-38.],
#         [ 66.],
#         [ 30.],
#         [ 90.],
#         [-22.],
#         [102.],
#         [ 14.],
#         [ 10.],
#         [ 38.],
#         [-14.]], dtype=float32)>,
#  <tf.Tensor: shape=(10, 1), dtype=float32, numpy=
#  array([[-42.43629  ],
#         [ 52.241455 ],
#         [ 19.468386 ],
#         [ 74.09016  ],
#         [-27.870483 ],
#         [ 85.01451  ],
#         [  4.902581 ],
#         [  1.2611296],
#         [ 26.751287 ],
#         [-20.58758  ]], dtype=float32)>)

# %%
mae = tf.reduce_mean(tf.abs(y_test - y_pred))
print(mae.numpy())
# Out:
# 10.316484

# %%
(tf.metrics.mean_absolute_error(y_test, y_pred)).numpy()
# Out:
# array([ 4.4362907, 13.758545 , 10.531614 , 15.909843 ,  5.8704834,
#        16.985489 ,  9.097419 ,  8.738871 , 11.248713 ,  6.5875797],
#       dtype=float32)

# %%
# y_test = tf.reshape(y_test, shape=(10,))
# y_pred = tf.reshape(y_pred, shape=(10,))
y_pred = tf.squeeze(y_pred)
y_test = tf.squeeze(y_test)

y_test, y_pred
# Out:
# (<tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([-38.,  66.,  30.,  90., -22., 102.,  14.,  10.,  38., -14.],
#        dtype=float32)>,
#  <tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([-42.43629  ,  52.241455 ,  19.468386 ,  74.09016  , -27.870483 ,
#          85.01451  ,   4.902581 ,   1.2611296,  26.751287 , -20.58758  ],
#        dtype=float32)>)

# %%
tf.metrics.mean_absolute_error(y_test, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.316484>

# %%
tf.metrics.mean_squared_error(y_pred, y_test)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=122.50462>

# %%
huber = tf.keras.losses.Huber()
huber(y_true=y_test, y_pred=y_pred).numpy()
# Out:
# 9.816484

# %% [markdown]
# ## Running experiments to improve the model
# 1. 1 Layer - 100 epochs
# 2. 2 layers -- 100 epochs
# 3. 2 layers -- 500 epochs
# 4. 2 layers Adam - lr = 0.001 100 Epochs
# 5. 2 layers Adam - lr = 0.001 500 epochs
# 6. 2 layers Adam -lr = 0.01 100 epochs

# %%
def calculate_mae_mse(y_true=y_test, 
                     y_pred=y_pred):
    return tf.metrics.mean_absolute_error(y_true, tf.squeeze(y_pred)).numpy(), tf.metrics.mean_squared_error(y_true, tf.squeeze(y_pred)).numpy()

# %%
# model_1

model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
], name='model_1')

model_1.compile(loss=tf.keras.losses.mae, 
             optimizer=tf.keras.optimizers.SGD(), 
             metrics=['mae', 'mse'])

model_1.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
y_preds_1 = model_1.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
y_preds_1
# Out:
# array([[-27.410488 ],
#        [ 34.626297 ],
#        [ 13.152026 ],
#        [ 48.94248  ],
#        [-17.866367 ],
#        [ 56.100567 ],
#        [  3.6079051],
#        [  1.221875 ],
#        [ 17.924086 ],
#        [-13.094306 ]], dtype=float32)

# %%
mae_1, mse_1 = calculate_mae_mse(y_true=y_test, y_pred=y_preds_1)
mae_1, mse_1
# Out:
# (19.00536, 577.878)

# %%
tf.random.set_seed(42)

model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),  # first layer
    tf.keras.layers.Dense(1)                        # output layer
], name='model_2')

model_2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.SGD(),
    metrics=['mae']
)

model_2.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
y_preds_2 = model_2.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
X_test
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([-48.,  56.,  20.,  80., -32.,  92.,   4.,   0.,  28., -24.],
#       dtype=float32)>

# %%
y_preds_2
# Out:
# array([[-11.752471  ],
#        [ 50.772346  ],
#        [ 18.468538  ],
#        [ 72.30822   ],
#        [ -7.6716814 ],
#        [ 83.07616   ],
#        [  4.1112914 ],
#        [  0.52202547],
#        [ 25.647163  ],
#        [ -5.6312866 ]], dtype=float32)

# %%
mae_2, mse_2 = calculate_mae_mse(y_true=y_test, y_pred=y_preds_2)
mae_2, mse_2
# Out:
# (14.403882, 234.04468)

# %%
# model_3 -- 2 layers -- 500 epochs

tf.random.set_seed(42)

model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(1)
], name='model_3')

model_3.compile(loss=tf.keras.losses.mae, 
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
               metrics=['mae'])

model_3.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
y_preds_3 = model_3.predict(X_test)
y_preds_3
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b45481ee660> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 25ms/step
# array([[-41.83972  ],
#        [ 64.70331  ],
#        [ 23.84739  ],
#        [ 91.94059  ],
#        [-27.79194  ],
#        [105.55923  ],
#        [  5.6737604],
#        [  1.0414875],
#        [ 32.926483 ],
#        [-20.768051 ]], dtype=float32)

# %%
mae_3, mse_3 = calculate_mae_mse(y_pred=y_preds_3)
mae_3, mse_3
# Out:
# (5.17071, 32.538837)

# %%
#model_4 -->2 layers Adam - lr = 0.001 500 Epochs

tf.random.set_seed(42)

model_4 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1)
], name='model_4')

model_4.compile(loss=tf.keras.losses.mae, 
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
               metrics=['mae'])

model_4.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=500, verbose=0) 
model_4.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 100)               200
#
#  dense_11 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 301 (1.18 KB)
# Trainable params: 301 (1.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
y_preds_4 = model_4.predict(X_test)
y_preds_4
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b45481cbb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 27ms/step
# array([[-37.985455],
#        [ 66.00873 ],
#        [ 30.010738],
#        [ 90.00738 ],
#        [-21.986351],
#        [102.00671 ],
#        [ 14.011636],
#        [ 10.011859],
#        [ 38.01029 ],
#        [-13.986794]], dtype=float32)

# %%
mae_4, mse_4 = calculate_mae_mse(y_pred=y_preds_4)
mae_4, mse_4
# Out:
# (0.010873318, 0.00012450185)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_4)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_1)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_2)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_3)

# %%
# model_5 - 2 layers , Adam 0.01, 100 epochs

tf.random.set_seed(42)

model_5 = tf.keras.Sequential([
    tf.keras.layers.Dense(100), 
    tf.keras.layers.Dense(1)
], name='model_5')

model_5.compile(loss=tf.keras.losses.mae, 
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
               metrics=[
                   tf.keras.metrics.MeanAbsoluteError(name='mae'),
                   tf.keras.metrics.MeanSquaredError(name='mse')
               ])

model_5.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)
model_5.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 100)               200
#
#  dense_15 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 301 (1.18 KB)
# Trainable params: 301 (1.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
y_preds_5 = model_5.predict(X_test)
y_preds_5
# Out:
# 1/1 [==============================] - 0s 26ms/step
# array([[-37.53494  ],
#        [ 65.477066 ],
#        [ 29.819067 ],
#        [ 89.24907  ],
#        [-21.686935 ],
#        [101.13506  ],
#        [ 13.9710655],
#        [ 10.009066 ],
#        [ 37.743065 ],
#        [-13.762935 ]], dtype=float32)

# %%
mae_5, mse_5 = calculate_mae_mse(y_pred=y_preds_5)
mae_5, mse_5
# Out:
# (0.3629861, 0.20556358)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_5)

# %%
mae_1, mse_1 = calculate_mae_mse(y_pred=y_preds_1)
mae_2, mse_2 = calculate_mae_mse(y_pred=y_preds_2)
mae_3, mse_3 = calculate_mae_mse(y_pred=y_preds_3)
mae_4, mse_4 = calculate_mae_mse(y_pred=y_preds_4)
mae_5, mse_5 = calculate_mae_mse(y_pred=y_preds_5)

# %%
# Comparing the results of the experiments 
# Create a pandas df 

model_results = [
    ['model_1', mae_1, mse_1],
    ['model_2', mae_2, mse_2],
    ['model_3', mae_3, mse_3], 
    ['model_4', mae_4, mse_4], 
    ['model_5', mae_5, mse_5]
]

eval_df = pd.DataFrame(data=model_results, columns=['model', 'mae', 'mse'])

# %%
eval_df
# Out:
#      model        mae         mse
# 0  model_1  19.005360  577.877991
# 1  model_2  14.403882  234.044678
# 2  model_3   5.170710   32.538837
# 3  model_4   0.010873    0.000125
# 4  model_5   0.362986    0.205564

# %% [markdown]
# ## Keep track of ecperiments - Tools
#
# 1. **TensorBoard** - a component of the TensorFlow library to help track modelling experiment
# 2. **Weights & Biases** https://wandb.ai/site/

# %% [markdown]
# ## Saving out models & Using Our Model
#
# Two formats
# 1. SavedModel format  && tf.keras.models.load_model
# 2. HDF5 Format

# %%
# Save and load model with SavedModel format 

model_4.save("../models/best_model_SavedModel_format")
# Out:
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1, 100), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7b45496b6030>, 135537508751664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(100,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7b482d1fda30>, 135537508539760), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(100, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7b45480da000>, 135537494194864), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7b45481022d0>, 135537494190064), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1, 100), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7b45496b6030>, 135537508751664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(100,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7b482d1fda30>, 135537508539760), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(100, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7b45480da000>, 135537494194864), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7b45481022d0>, 135537494190064), {}).
# INFO:tensorflow:Assets written to: ../models/best_model_SavedModel_format/assets

# %%
# Save model with HDF5 Format -- We get a single file
model_4.save('../models/best_model_HDF5_format.h5')

# %%
loaded_model_saved_model = tf.keras.models.load_model(
    '../models/best_model_SavedModel_format', 
)
loaded_model_saved_model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 100)               200
#
#  dense_11 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 301 (1.18 KB)
# Trainable params: 301 (1.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loaded_model_hdf5_format = tf.keras.models.load_model('../models/best_model_HDF5_format.h5') 
loaded_model_hdf5_format.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 100)               200
#
#  dense_11 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 301 (1.18 KB)
# Trainable params: 301 (1.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loaded_model_saved_model.predict(X_test) == loaded_model_hdf5_format.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
loaded_model_hdf5_format.predict(X_test) == model_4.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
loaded_model_hdf5_format.evaluate(X_test, y_test) == loaded_model_saved_model.evaluate(X_test, y_test) == model_4.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0109 - mae: 0.0109
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0109 - mae: 0.0109
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0109 - mae: 0.0109
# True
